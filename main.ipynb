# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a>b:
        return a
    elif b>a:
        return b
    else:
        print('Warning, both numbers are equal')
        return a
#your code here

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.019s
#
# OK

# %%
#your code here

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
#your code here
def greatest(lst):
    g = lst[0]
    for n in lst:
        if n > g:
            g = n
    
    return g

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.018s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
    res = 0
    for e in lst:
        if isinstance(e,(int,float)):
            res += e
    
    return res

#your code here
# Out:
# 6.5

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.026s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
    res = 1
    for e in lst:
        res *= e
    return res
#your code here

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.021s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper = "*"):
    if oper == '*':
        return mult_all(arr)
    elif oper == '+':
        return sum_all(arr)
    else:
        print('Please provide "+" or "*" as second argument.')
        return None
#your code here

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.026s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    if n in [0,1]:
        return 1
    else:
        res = n * factorial(n-1)
        return res
#your code here

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.021s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):
    reslist = []
    for e in lst_un:
        if e not in reslist:
            reslist.append(e)
    return reslist
#your code here
# Out:
# [1, 2, 4, 6]

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.053s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    
    # create dictionary of counters for each element in list
    counters = {}
    for e in arr:
        if not counters.get(e):
            counters[e] = 1
        else:
            counters[e] +=1
    
    # get list of counter values
    freqlist = list(counters.values())
    # get list of keys
    keylist = list(counters.keys())
    # identify index of largest value
    largest_idx = freqlist.index(greatest(freqlist))
    # return the key at the index for largest value
    return keylist[largest_idx]
    
mode_counter(['a','gr',2,3,4,3,'gr','gr'])
    
#your code here
# Out:
# 'gr'

# %%
# sketchboard
t = {'a': 1, 'house': 62, 'b': 2}

greatest(list(t.values()))
idx = list(t.values()).index(greatest(list(t.values())))
elementlist = list(t.keys())
elementlist[idx]
# Out:
# 'house'

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.025s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def length(lst):
    counter = 0
    for e in lst:
        counter += 1
    return counter

# %%
# population standard deviation
# sqrt(sum((x-mean)**2)/number of observations)

# sample standard deviation
# sqrt(sum((x-mean)**2)/number of observations - 1)


def st_dev(list_sd):
    # get N
    l_of_list = length(list_sd)
    # get mean of distribution
    mean = sum_all(list_sd)/l_of_list
    # return square root of ((sum of squared differences between each value in distribution from mean) divided by N)
    top = sum_all([(x-mean)**2 for x in list_sd])
    variance = top/(l_of_list-1)
    return variance**(1/2)
        

tlist=[1,2]
print(st_dev(tlist))
print(stdev(tlist))
#your code here
# Out:
# 0.7071067811865476
# 0.7071067811865476

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.031s
#
# OK
# ...

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    # build a list of all ascii letters (only lower case for now?)
    # to save some typing work, I create a range and then convert that to strings
    alphabet = [chr(c) for c in range(97,123)]
    for l in alphabet:
        if l not in string.lower():
            return False
    
    return True
#your code here

pangram('The quick brown fox jumps over the lazy dog.')
pangram('test')
# Out:
# False

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.007s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    tmpstring=''
    lst=[]
    for c in string:
        if c ==' ':
            continue
        elif c != ',':
            tmpstring += c
        else:
            lst.append(tmpstring)
            tmpstring = ''
        
    lst.append(tmpstring)
    lst = sorted(lst)
    
    targetstring = lst[0]
    for s in lst[1:]:
        # nicer option with spaces commented out to accomodate test algorithm
 #       targetstring += ', '
        targetstring += ','
        targetstring += s
        
    
    return(targetstring)
#your code here

# %%
str1 = 'all, evidence, bears'

print(sort_alpha(str1))
# Out:
# all,bears,evidence

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.023s
#
# OK

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
    low=False
    up=False
    num=False
    spec=False
    min8=False
    
    counter = 0
    special_chars = '!§^$%&@/()=?+"\[]}{*#-_.,;:<>|'
        
    for c in password:
        counter+=1
        if counter > 7:
            min8 = True
        if ord(c) >=64 and ord(c)<=90:
            up=True
        elif ord(c) >=97 and ord(c)<=122:
            low=True
        elif ord(c) >=48 and ord(c)<=57:
            num=True
        elif c in special_chars:        # ok, I'm not going to test all special char ASCII areas separately
            spec=True
        
        if low==up==num==spec==min8==True:
            return True
    
    return False
            
#your code here

# %%
pw1 = 'Pw2!'
pw2= 'Pw2!Wackelpudding'
print(check_pass(pw1))
print(check_pass(pw2))
# Out:
# False
# True

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.024s
#
# OK
